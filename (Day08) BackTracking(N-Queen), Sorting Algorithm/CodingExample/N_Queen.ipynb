# %% [markdown]
# problem 1)
#
# https://www.acmicpc.net/problem/2239

# %% [markdown]
# 경우의 수:
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np


# 9 * 9 배열로 정의, element는 1~9까지의 숫자 중 하나이며, 빈칸은 0으로 표시
# 특정 숫자가 특정 위치에 들어갈 수 있는지 확인 (행, 열, 3*3박스 내에서 중복되는지 확인하기)
# 값이 0인 칸을 찾기.

# 빈 칸에 대해 가능한 숫자를 시도 --> 유효한지 확인
# 유효하면 숫자 삽입
# 유효하지 않으면 백트래킹해서 다른 숫자를 시도

# 만약 모든 칸을 숫자로 채우면 완료, 결과를 반환
# 못채우면 해결할 수 없음.

def solution():
  a = map(int, input().split())
  print(type(a))

solution()
# Out:
# 103000509 002109400 000704000 300502006 060000050 700803004 000401000 009205800 804000107
# <class 'map'>

# %% [markdown]
# Problem 2)
#
# https://school.programmers.co.kr/learn/courses/30/lessons/60062
