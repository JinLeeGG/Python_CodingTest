# %% [markdown]
# ## Problem1)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Problem 2)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
road1 = [[1,2,1],[2,3,3],[5,2,2],[1,4,2],[5,3,1],[5,4,2]]

def solution(N, road, K)
    node = []
    minimum_cost = []
    post_node = []

    # [1, 2, 1]
    # [start, end, value]
    tuple1 = (node, minimum_cost, post_node)

    # 1, 2  -> 1
    # 2, 1  -> 1

    # 1, 4  -> 2
    # 4, 1  -> 2

    # 2, 3  -> 3
    # 3, 2  -> 3

    # 5, 2  -> 2
    # 2, 5  -> 2

    # 5, 3  -> 1
    # 3, 5  -> 1

    # 5, 4  -> 2
    # 4, 5  -> 2


    # 1 -> 2  : 1

    # 1 -> 3 , 1 -> 2 -> 3 : 4
    # 1 -> 3 ,
e

    # 1 -> 4  : 2

    # 1 -> 5, 1 -> 4 -> 5 : 4
