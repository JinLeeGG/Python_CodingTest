# %% [markdown]
# ## Problem 1
# ![image.png](data:image/png;base64,...)

# %%
# my answer:

def solution(n, money):
    result = 0
    greed = []
    counter = 1

  # how many currency do we have?

    for i in money:
        # print(i)
        print(money[i])
        if i < len(money) and counter <= money[i]:
          if n - (counter * money[i]) == 0:
            result += 1
            counter += 1
            print(result)
        counter == 0

    for i in money:
        print(i)





    # print(result)


solution(5, [1,2,5])
# Out:
# 1
# 2
# 5

# %% [markdown]
# Problem2)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Problem3)
#
# ![image.png](data:image/png;base64,...)
